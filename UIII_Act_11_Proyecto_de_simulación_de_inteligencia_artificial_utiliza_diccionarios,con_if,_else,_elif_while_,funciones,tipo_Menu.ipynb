# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisGuzman128/UIII-Act-11-Proyecto-de-simulaci-n-de-inteligencia-artificial-utiliza-diccionarios/blob/main/UIII_Act_11_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_utiliza_diccionarios%2Ccon_if%2C_else%2C_elif_while_%2Cfunciones%2Ctipo_Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 22/mayo/2026

# INGENIERO:
# Rama de ingeniería, proyectos firmados,
# colegiación, software de cálculo,
# presupuesto de obra y experiencia en campo.

# ======================================================
# 🏗️ CBTis 128
# 📚 Elabora Proyectos de Programación Lógica
# 🤖 Especialidad: Inteligencia Artificial
# 👨‍🏫 Docente: Manuel Nava
# 👨‍🎓 Alumno: Axel Guzman NL = 27
# 🏗️ Proyecto: Diccionario de Ingenieros
# ======================================================

# =========================
# 🏗️ Diccionario vacío
# =========================
ingenieros = {}

# =========================
# ➕ Agregar ingeniero
# =========================
def agregar_ingeniero():

    clave = input("Ingresa clave del ingeniero: ")
    rama = input("Ingresa rama de ingeniería: ")
    proyectos = input("Ingresa proyectos firmados: ")
    colegiacion = input("Ingresa colegiación: ")
    software = input("Ingresa software de cálculo: ")
    presupuesto = input("Ingresa presupuesto de obra: ")
    experiencia = input("Ingresa experiencia en campo: ")

    ingenieros[clave] = {

        "Rama": rama,
        "Proyectos": proyectos,
        "Colegiacion": colegiacion,
        "Software": software,
        "Presupuesto": presupuesto,
        "Experiencia": experiencia
    }

    print("\n✅ Ingeniero agregado correctamente")

    listar_ingenieros()

# =========================
# 📜 Listar ingenieros
# =========================
def listar_ingenieros():

    print("\n===================================================================================================================================================")
    print(f"{'CLAVE':<12}{'RAMA':<20}{'PROYECTOS':<22}{'COLEGIACION':<18}{'SOFTWARE':<20}{'PRESUPUESTO':<20}{'EXPERIENCIA':<20}")
    print("===================================================================================================================================================")

    for key, value in ingenieros.items():

        print(f"{key:<12}"
              f"{value['Rama']:<20}"
              f"{value['Proyectos']:<22}"
              f"{value['Colegiacion']:<18}"
              f"{value['Software']:<20}"
              f"{value['Presupuesto']:<20}"
              f"{value['Experiencia']:<20}")

    print("===================================================================================================================================================")

# =========================
# 🔍 Buscar ingeniero
# =========================
def buscar_ingeniero():

    buscar = input("Ingresa clave del ingeniero: ")

    if buscar in ingenieros:

        print("\n===================================================================================================================================================")
        print(f"{'CLAVE':<12}{'RAMA':<20}{'PROYECTOS':<22}{'COLEGIACION':<18}{'SOFTWARE':<20}{'PRESUPUESTO':<20}{'EXPERIENCIA':<20}")
        print("===================================================================================================================================================")

        value = ingenieros[buscar]

        print(f"{buscar:<12}"
              f"{value['Rama']:<20}"
              f"{value['Proyectos']:<22}"
              f"{value['Colegiacion']:<18}"
              f"{value['Software']:<20}"
              f"{value['Presupuesto']:<20}"
              f"{value['Experiencia']:<20}")

        print("===================================================================================================================================================")

    else:
        print("❌ Ingeniero no encontrado")

# =========================
# ❌ Borrar ingeniero
# =========================
def borrar_ingeniero():

    borrar = input("Ingresa clave del ingeniero a borrar: ")

    if borrar in ingenieros:

        del ingenieros[borrar]

        print("\n✅ Ingeniero eliminado correctamente")

        listar_ingenieros()

    else:
        print("❌ Ingeniero no encontrado")

# =========================
# ✏️ Actualizar ingeniero
# =========================
def actualizar_ingeniero():

    actualizar = input("Ingresa clave del ingeniero: ")

    if actualizar in ingenieros:

        rama = input("Nueva rama de ingeniería: ")
        proyectos = input("Nuevos proyectos firmados: ")
        colegiacion = input("Nueva colegiación: ")
        software = input("Nuevo software de cálculo: ")
        presupuesto = input("Nuevo presupuesto de obra: ")
        experiencia = input("Nueva experiencia en campo: ")

        ingenieros[actualizar] = {

            "Rama": rama,
            "Proyectos": proyectos,
            "Colegiacion": colegiacion,
            "Software": software,
            "Presupuesto": presupuesto,
            "Experiencia": experiencia
        }

        print("\n✅ Ingeniero actualizado correctamente")

        listar_ingenieros()

    else:
        print("❌ Ingeniero no encontrado")

# =========================
# 📌 Menú principal
# =========================
while True:

    print("\n=========== MENÚ INGENIERO 🏗️ ===========")
    print("1. Agregar ingeniero")
    print("2. Listar ingenieros")
    print("3. Buscar ingeniero")
    print("4. Borrar ingeniero")
    print("5. Actualizar ingeniero")
    print("6. Salir")

    opcion = int(input("Selecciona una opción: "))

    if opcion == 1:
        agregar_ingeniero()

    elif opcion == 2:
        listar_ingenieros()

    elif opcion == 3:
        buscar_ingeniero()

    elif opcion == 4:
        borrar_ingeniero()

    elif opcion == 5:
        actualizar_ingeniero()

    elif opcion == 6:
        print("🏗️ Programa finalizado")
        break

    else:
        print("❌ Opción no válida")
# Out:
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 1
# Ingresa clave del ingeniero: ING01
# Ingresa rama de ingeniería: Civil
# Ingresa proyectos firmados: Plaza Comercial
# Ingresa colegiación: Activa
# Ingresa software de cálculo: AutoCAD
# Ingresa presupuesto de obra: 2500000
# Ingresa experiencia en campo: 8 años
#
# ✅ Ingeniero agregado correctamente
#
# ===================================================================================================================================================
# CLAVE       RAMA                PROYECTOS             COLEGIACION       SOFTWARE            PRESUPUESTO         EXPERIENCIA
# ===================================================================================================================================================
# ING01       Civil               Plaza Comercial       Activa            AutoCAD             2500000             8 años
# ===================================================================================================================================================
#
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 1
# Ingresa clave del ingeniero: ING02
# Ingresa rama de ingeniería: Industrial
# Ingresa proyectos firmados: Planta Automotriz
# Ingresa colegiación: Vigente
# Ingresa software de cálculo: SolidWorks
# Ingresa presupuesto de obra: 4200000
# Ingresa experiencia en campo: 5 años
#
# ✅ Ingeniero agregado correctamente
#
# ===================================================================================================================================================
# CLAVE       RAMA                PROYECTOS             COLEGIACION       SOFTWARE            PRESUPUESTO         EXPERIENCIA
# ===================================================================================================================================================
# ING01       Civil               Plaza Comercial       Activa            AutoCAD             2500000             8 años
# ING02       Industrial          Planta Automotriz     Vigente           SolidWorks          4200000             5 años
# ===================================================================================================================================================
#
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 1
# Ingresa clave del ingeniero: ING03
# Ingresa rama de ingeniería: Mecánica
# Ingresa proyectos firmados: Sistema Hidráulico
# Ingresa colegiación: Certificada
# Ingresa software de cálculo: MATLAB
# Ingresa presupuesto de obra: 1800000
# Ingresa experiencia en campo: 10 años
#
# ✅ Ingeniero agregado correctamente
#
# ===================================================================================================================================================
# CLAVE       RAMA                PROYECTOS             COLEGIACION       SOFTWARE            PRESUPUESTO         EXPERIENCIA
# ===================================================================================================================================================
# ING01       Civil               Plaza Comercial       Activa            AutoCAD             2500000             8 años
# ING02       Industrial          Planta Automotriz     Vigente           SolidWorks          4200000             5 años
# ING03       Mecánica            Sistema Hidráulico    Certificada       MATLAB              1800000             10 años
# ===================================================================================================================================================
#
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 2
#
# ===================================================================================================================================================
# CLAVE       RAMA                PROYECTOS             COLEGIACION       SOFTWARE            PRESUPUESTO         EXPERIENCIA
# ===================================================================================================================================================
# ING01       Civil               Plaza Comercial       Activa            AutoCAD             2500000             8 años
# ING02       Industrial          Planta Automotriz     Vigente           SolidWorks          4200000             5 años
# ING03       Mecánica            Sistema Hidráulico    Certificada       MATLAB              1800000             10 años
# ===================================================================================================================================================
#
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 3
# Ingresa clave del ingeniero: ING03
#
# ===================================================================================================================================================
# CLAVE       RAMA                PROYECTOS             COLEGIACION       SOFTWARE            PRESUPUESTO         EXPERIENCIA
# ===================================================================================================================================================
# ING03       Mecánica            Sistema Hidráulico    Certificada       MATLAB              1800000             10 años
# ===================================================================================================================================================
#
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 4
# Ingresa clave del ingeniero a borrar: ING02
#
# ✅ Ingeniero eliminado correctamente
#
# ===================================================================================================================================================
# CLAVE       RAMA                PROYECTOS             COLEGIACION       SOFTWARE            PRESUPUESTO         EXPERIENCIA
# ===================================================================================================================================================
# ING01       Civil               Plaza Comercial       Activa            AutoCAD             2500000             8 años
# ING03       Mecánica            Sistema Hidráulico    Certificada       MATLAB              1800000             10 años
# ===================================================================================================================================================
#
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 5
# Ingresa clave del ingeniero: ING01
# Nueva rama de ingeniería: civil
# Nuevos proyectos firmados: sistema hidraulico
# Nueva colegiación: certificada
# Nuevo software de cálculo: AutoCAD
# Nuevo presupuesto de obra: 180000
# Nueva experiencia en campo: 10 años
#
# ✅ Ingeniero actualizado correctamente
#
# ===================================================================================================================================================
# CLAVE       RAMA                PROYECTOS             COLEGIACION       SOFTWARE            PRESUPUESTO         EXPERIENCIA
# ===================================================================================================================================================
# ING01       civil               sistema hidraulico    certificada       AutoCAD             180000              10 años
# ING03       Mecánica            Sistema Hidráulico    Certificada       MATLAB              1800000             10 años
# ===================================================================================================================================================
#
# =========== MENÚ INGENIERO 🏗️ ===========
# 1. Agregar ingeniero
# 2. Listar ingenieros
# 3. Buscar ingeniero
# 4. Borrar ingeniero
# 5. Actualizar ingeniero
# 6. Salir
# Selecciona una opción: 6
# 🏗️ Programa finalizado
